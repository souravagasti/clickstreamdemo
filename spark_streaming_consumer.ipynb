# %%
from spark_init import get_spark_session

spark = get_spark_session()
topic = "orders"

stream = spark.readStream \
    .format("kafka") \
    .option("kafka.bootstrap.servers", "localhost:9092") \
    .option("subscribe", topic) \
    .load()
     # .option("startingOffsets", "earliest") \

query1 = (stream.writeStream \
    .format("console") \
    .outputMode("append")\
    # .option("kafka.bootstrap.servers", "localhost:9092") \
    # .option("topic", "orders1") \
    .option("checkpointLocation", "/tmp/orders-checkpoint1") \
    # .trigger(processingTime="5 seconds")\
    .start()
)

# %%
query1 = (stream.writeStream \
    .format("console") \
    .outputMode("append")\
    # .option("kafka.bootstrap.servers", "localhost:9092") \
    # .option("topic", "orders1") \
    .option("checkpointLocation", "/tmp/orders-checkpoint1") \
    # .trigger(processingTime="5 seconds")\
    .start()
)
# Out:
# 26/09/10 22:57:32 WARN ResolveWriteToStream: spark.sql.adaptive.enabled is not supported in streaming DataFrames/Datasets and will be disabled.
# 26/09/10 22:57:32 ERROR MicroBatchExecution: Query [id = c99ee8be-dae2-4957-940c-5e247aa91a15, runId = 776985cf-b7dd-4df3-b34b-72c26ec92d31] terminated with error
# org.apache.spark.sql.kafka010.KafkaIllegalStateException: Some data may have been lost because they are not available in Kafka any more;
# either the data was aged out by Kafka or the topic may have been deleted before all the data in the
# topic was processed.
# If you don't want your streaming query to fail on such cases, set the source option failOnDataLoss to false.
# Reason: Partitions Set(events-0, events-1, events-2) have been deleted.
# 	at org.apache.spark.sql.kafka010.KafkaExceptions$.partitionsDeleted(KafkaExceptions.scala:141)
# 	at org.apache.spark.sql.kafka010.KafkaOffsetReaderBase.$anonfun$getOffsetRangesFromResolvedOffsets$6(KafkaOffsetReader.scala:228)
# ...
